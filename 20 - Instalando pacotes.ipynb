# %% [markdown]
# #Instalando um pacote no Google Colab

# %%
pip install emoji
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 358.9/358.9 kB 4.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# #Carregando um paconte instalado

# %%
#Você precisa carregar o pacote antes de começar a usar
import emoji

# %%
print(emoji.emojize('Python é :thumbs_up:'))
# Out:
# Python é 👍

# %%
print(emoji.emojize('Eu :red_heart: aprender Python'))
# Out:
# Eu ❤️ aprender Python
