# %% [markdown]
# #Operadores relacionais

# %% [markdown]
# * maior >
# * menor <
# * igual ==
# * maior igual >=
# * menor igual <=
# *diferente !=

# %%
10 > 20
# Out:
# False

# %%
10<20
# Out:
# True

# %%
nome_aluno = "Vinicius"
professor = "Vinicius"

# %%
nome_aluno == professor
# Out:
# True

# %%
nome_aluno1 ="Pedro"
professor1 ="Fernando"

# %%
nome_aluno1 == professor1
# Out:
# False

# %% [markdown]
# #Operadores Lógicos

# %% [markdown]
# * AND (e)
# * OR (ou)
# * NOT(no)

# %% [markdown]
# #AND

# %% [markdown]
# **Tabela Verdade AND(E)**
#
# True + True = True
#
# True + False = False
#
# False + True = False
#
# False + False = False

# %%
(10>20)and(20>30)
# Out:
# False

# %%
(10<20)and (20<30)
# Out:
# True

# %% [markdown]
# #OR

# %% [markdown]
# **Tabela Verdade(OR)**
#
# True + True = True
#
# Truee + False = True
#
# False + True = True
#
# False + False = False

# %%
(1<2)or(3>6)
# Out:
# True

# %%
"Vinicius"=="Vinicius" or "Python"!="python"
# Out:
# True

# %% [markdown]
# #NOT

# %% [markdown]
# True = False
#
# False = True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
(10<20)and (20<30)
# Out:
# True

# %%
not (10<20)and (20<30)
# Out:
# False
