# %% [markdown]
# # Função PRINT ()

# %% [markdown]
# A função print () é uma das funções mais importantes da linguagem Python. Sua Função é, basicamente, exibir mensagens na tela ou enviá-las para outro dispositivo, como imprimir dentro de arquivos de texto.
#
# No Python 3, print é uma função interna, de modo que não é necessário importar nenhuma biblioteca para poder utilizá-la. Basta chamá-la e passar os argumentos necessários.

# %%
print('Meu primeiro print')
# Out:
# Meu primeiro print

# %%
print("Meu primeiro print")
# Out:
# Meu primeiro print

# %%
#Frase com apóstrofo colocar aspas no comando print
print("D'água")
# Out:
# D'água

# %%
10*300
# Out:
# 3000

# %%
20*50
# Out:
# 1000

# %%
20*5
125*4
# Out:
# 500

# %%
print(20*50)
print(125*4)
# Out:
# 1000
# 500

# %%
print(12345)
# Out:
# 12345

# %%
nome = "Susie"

# %%
print(nome)
# Out:
# Susie

# %%
print('Susie, 20 de agosto, Estudo de Python')
# Out:
# Susie, 20 de agosto, Estudo de Python
